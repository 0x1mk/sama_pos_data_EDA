# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

session = requests.Session()

# Make a request to the webpage using the session
url = 'https://www.sama.gov.sa/ar-sa/Indices/pages/pos.aspx'
response = session.get(url,headers={"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"
})


# Parse the HTML of the page
soup = BeautifulSoup(response.text, 'html.parser')

# Find all the `tr` elements with class "gridalter"
rows = soup.find_all('tr', class_='gridalter')

# Extract the href values from the rows
for row in rows:
    # Find all the `a` elements within the row
    links = row.find_all('a', href=True)

    # Print the `href` attribute of each link
    for link in links:
        print(link['href'])

# %%
href_values = [
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_31st-Dec-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_17th-Dec-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_3rd-Dec-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_19th-Nov-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_5th-Nov-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_22nd-Oct-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_8th_Oct_2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_24th-Sep-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_10th-Sep-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_27th-Aug-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_13th-Aug-2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_30th_Jul_2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_16th_Jul_2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_18th_Jun_2022.pdf',
    '/ar-sa/Indices/POS/Weekly_Points_of_Sale_Transactions_Report_4th-Jun-2022.pdf',
    ]

# %%
base_url = 'https://www.sama.gov.sa'

for href in href_values:
    # Construct the full URL of the PDF file
    pdf_url = base_url + href

    # Download the PDF file
    response = requests.get(pdf_url,headers={"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"
})

    # Save the PDF file to the current directory
    with open(href.split('/')[-1], 'wb') as f:
        f.write(response.content)

# %%
import requests
from bs4 import BeautifulSoup

# Create an HTTP session
session = requests.Session()

# Make a request to the webpage using the session
url = 'https://www.sama.gov.sa/ar-sa/Indices/pages/pos.aspx'
response = session.get(url, headers={
"User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"
})

# Parse the HTML content of the webpage
soup = BeautifulSoup(response.content, 'html.parser')

# Find all the `a` elements that have an `href` attribute
links = soup.find_all('a', href=True)

# Print the `href` attribute of each link
for link in links:
    print(link['href'])
# Out:
# http://www.sama.gov.sa/ar-sa
# http://www.sama.gov.sa/ar-sa/News/Pages/allnews.aspx
# http://www.sama.gov.sa/ar-sa/LawsRegulations
# http://www.sama.gov.sa/ar-sa/LawsRegulations/Pages/BankingLaws.aspx
# http://www.sama.gov.sa/ar-sa/LawsRegulations/Pages/FinanceLaws.aspx
# http://www.sama.gov.sa/ar-sa/LawsRegulations/Pages/InsuranceLaws.aspx
# http://www.sama.gov.sa/ar-sa/LawsRegulations/Pages/AMLRules.aspx
# http://www.sama.gov.sa/ar-sa/LawsRegulations/Pages/MoneyExchangeLaws.aspx
# http://www.sama.gov.sa/ar-sa/LawsRegulations/Pages/CreditInformation.aspx
# http://www.sama.gov.sa/ar-sa/LawsRegulations/Pages/Payments.aspx
# http://www.sama.gov.sa/ar-sa/RulesInstructions/Pages/default.aspx
# http://www.sama.gov.sa/ar-sa/RulesInstructions/Pages/FinanceRulesAndRegulations.aspx
# http://www.sama.gov.sa/ar-sa/RulesInstructions/Pages/BankingRulesAndRegulations.aspx
# http://www.sama.gov.sa/ar-sa/RulesInstructions/Pages/InsuranceRulesAndRegulation.aspx
# ...
